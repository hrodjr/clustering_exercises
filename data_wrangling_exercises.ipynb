# %%
import pandas as pd
import numpy

import acquire
import env

# %%
df = acquire.get_zillow_data()
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-012768b18099> in <module>
# ----> 1 df = acquire.get_zillow_data()
#       2 df.head(2)
#
# ~/codeup-data-science/clustering_exercises/acquire.py in get_zillow_data()
#      29 #acquires zillow dataset
#      30 def get_zillow_data():
# ---> 31     return pd.read_sql(zillow_sql,get_connection('zillow'))
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     519         )
#     520     else:
# --> 521         return pandas_sql.read_query(
#     522             sql,
#     523             index_col=index_col,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
# ...
